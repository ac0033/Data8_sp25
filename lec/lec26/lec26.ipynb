# %%
import matplotlib
from datascience import *
# %matplotlib inline
import matplotlib.pyplot as plots
import numpy as np
plots.style.use('fivethirtyeight')

# %% [markdown]
# ## Review

# %% [markdown]
# **Question**

# %% [markdown]
# ______

# %%
united = Table.read_table('united.csv')

# %%
united.show(6)
# Out:
# <table border="1" class="dataframe">
#     <thead>
#         <tr>
#             <th>Date</th> <th>Flight Number</th> <th>Destination</th> <th>Delay</th>
#         </tr>
#     </thead>
#     <tbody>
#         <tr>
#             <td>6/1/15</td> <td>73           </td> <td>HNL        </td> <td>257  </td>
#         </tr>
#         <tr>
#             <td>6/1/15</td> <td>217          </td> <td>EWR        </td> <td>28   </td>
#         </tr>
#         <tr>
#             <td>6/1/15</td> <td>237          </td> <td>STL        </td> <td>-3   </td>
#         </tr>
#         <tr>
#             <td>6/1/15</td> <td>250          </td> <td>SAN        </td> <td>0    </td>
#         </tr>
#         <tr>
#             <td>6/1/15</td> <td>267          </td> <td>PHL        </td> <td>64   </td>
#         </tr>
#         <tr>
#             <td>6/1/15</td> <td>273          </td> <td>SEA        </td> <td>-6   </td>
#         </tr>
#     </tbody>
# </table>
# <p>... (13819 rows omitted)</p>

# %% [markdown]
# **Reminder:** We are treating this dataset as the population of all United Airlines flights that occurred over the two month period.

# %%
population_parameter = np.average(united.column('Delay'))
population_parameter
# Out:
# 16.658155515370705

# %% [markdown]
# **Question**

# %% [markdown]
# _____

# %%
births = Table.read_table('baby.csv')
births.show(6)
# Out:
# <table border="1" class="dataframe">
#     <thead>
#         <tr>
#             <th>Birth Weight</th> <th>Gestational Days</th> <th>Maternal Age</th> <th>Maternal Height</th> <th>Maternal Pregnancy Weight</th> <th>Maternal Smoker</th>
#         </tr>
#     </thead>
#     <tbody>
#         <tr>
#             <td>120         </td> <td>284             </td> <td>27          </td> <td>62             </td> <td>100                      </td> <td>False          </td>
#         </tr>
#         <tr>
#             <td>113         </td> <td>282             </td> <td>33          </td> <td>64             </td> <td>135                      </td> <td>False          </td>
#         </tr>
#         <tr>
#             <td>128         </td> <td>279             </td> <td>28          </td> <td>64             </td> <td>115                      </td> <td>True           </td>
#         </tr>
#         <tr>
#             <td>108         </td> <td>282             </td> <td>23          </td> <td>67             </td> <td>125                      </td> <td>True           </td>
#         </tr>
#         <tr>
#             <td>136         </td> <td>286             </td> <td>25          </td> <td>62             </td> <td>93                       </td> <td>False          </td>
#         </tr>
#         <tr>
#             <td>138         </td> <td>244             </td> <td>33          </td> <td>62             </td> <td>178                      </td> <td>False          </td>
#         </tr>
#     </tbody>
# </table>
# <p>... (1168 rows omitted)</p>

# %% [markdown]
# **Reminder:** We are treating this dataset as a random sample from a hosptial system.

# %%
births.hist('Birth Weight')
plots.show()

# %% [markdown]
# ## New material

# %% [markdown]
# ### A bell shape tells us more about a distribution

# %%
def chebyshev(num_SDs):
    # returns the least proportion of the data in +/- num_SDs
    z = num_SDs
    return 1 - 1/z**2

# %%
chebyshev(make_array(1,2,3))
# Out:
# array([ 0.        ,  0.75      ,  0.88888889])

# %% [markdown]
# **Task**: Empirically verify that for a bell shaped distribution,
# - the proportion of values within 1, 2 and 3 SDs of the mean is 68, 95, and 99.75 percent, respectively.

# %%
birth_weight_mean = np.average(births.column('Birth Weight'))
birth_weight_mean
# Out:
# 119.46252129471891

# %%
birth_weight_sd = np.std(births.column('Birth Weight'))
birth_weight_sd
# Out:
# 18.320863702202779

# %% [markdown]
# ###### Within 1 SD

# %%
births.where('Birth Weight', are.between(birth_weight_mean - birth_weight_sd,
                                        birth_weight_mean + birth_weight_sd)).num_rows/births.num_rows
# Out:
# 0.692504258943782

# %% [markdown]
# ###### Within 2 SD

# %%
births.where('Birth Weight', are.between(birth_weight_mean - 2*birth_weight_sd,
                                        birth_weight_mean + 2*birth_weight_sd)).num_rows/births.num_rows
# Out:
# 0.948892674616695

# %%
births.where('Birth Weight', are.between(birth_weight_mean - 3*birth_weight_sd,
                                        birth_weight_mean + 3*birth_weight_sd)).num_rows/births.num_rows
# Out:
# 0.995741056218058

# %% [markdown]
# **STOP**

# %% [markdown]
# ### The Central Limit Theorem (CLT)

# %% [markdown]
# **Task**: Show that the empirical distribution of the sample mean approaches a bell shape as the sample size (for each statistic used to create the distribution) increases.
#
# - Though the CLT is a statement about the probability distribution of the statistic, the empirical distribution will look roughly like the probability distribution when the repetition size is large. Here, we set it to 10,000.

# %%
def one_sample_mean(sample_size):
    """ 
    Takes a sample from the population of flights 
    and computes its mean
    """
    sampled_flights = united.sample(sample_size)
    return np.mean(sampled_flights.column('Delay'))

# %%
def ten_thousand_sample_means(sample_size):
    means = make_array()
    for i in np.arange(10000):
        mean = one_sample_mean(sample_size)
        means = np.append(means, mean)
    return means

# %%
def plot_sample_mean_distribution(sample_size):
    sample_means = ten_thousand_sample_means(sample_size)
    
    Table().with_column('Mean of ' + str(sample_size) + ' flight delays', 
                        sample_means).hist(bins=20)
    plots.show()

    print('Population Average:', population_parameter)

# %%
plot_sample_mean_distribution(10)
# Out:
# Population Average: 16.6581555154

# %%
plot_sample_mean_distribution(30)
# Out:
# Population Average: 16.6581555154

# %%
plot_sample_mean_distribution(100)
# Out:
# Population Average: 16.6581555154

# %%
plot_sample_mean_distribution(400)
# Out:
# Population Average: 16.6581555154

# %% [markdown]
# **Discussion Question** [2 min]
#
# After rolling 1,000,000 fair 6-sided dice, which of these histograms would you expect to have a bell shape?
# - You might expect there to be one (or more than one)!
#
# **1.** The histogram of outcomes of these million rolls
#
# **2.** The histogram that results from computing the average outcome of these million rolls
#
# **3.** The histogram that results from:
#  - splitting the outcomes into 1,000 groups of 1,000 (in the order they occurred)
#  - and computing the average outcome of each group

# %% [markdown]
# ###### Histogram 1

# %%
die = make_array(1,2,3,4,5,6)

# %%
one_million_die_rolls = np.random.choice(die,size = 1000000)

# %%
Table().with_columns('Die Spot', one_million_die_rolls).hist(bins = np.arange(1,8))
plots.show()

# %% [markdown]
# ###### Histogram 2

# %%
one_million_die_average = np.average(one_million_die_rolls)
one_million_die_average
# Out:
# 3.4955250000000002

# %%
Table().with_columns('Average', one_million_die_average).hist(bins = np.arange(1,8))
plots.title('This is not much of a histogram!')
plots.show();

# %% [markdown]
# ###### Histogram 3

# %%
one_million_roll_table = Table().with_columns('Die Spot', one_million_die_rolls)

# %%
np.average(one_million_roll_table.take(np.arange(1000)).column('Die Spot'))
# Out:
# 3.6000000000000001

# %%
group_averages = make_array()
for start in np.arange(0, 10**6, 1000):
    group_average = np.average(one_million_roll_table.take(np.arange(start, start + 1000)).column('Die Spot'))
    group_averages = np.append(group_averages, group_average)

# %%
group_averages
# Out:
# array([ 3.6  ,  3.582,  3.476,  3.583,  3.476,  3.511,  3.538,  3.437,
#         3.55 ,  3.591,  3.481,  3.596,  3.449,  3.405,  3.482,  3.579,
#         3.507,  3.504,  3.476,  3.527,  3.537,  3.617,  3.486,  3.449,
#         3.531,  3.489,  3.512,  3.39 ,  3.527,  3.549,  3.447,  3.466,
#         3.457,  3.499,  3.555,  3.484,  3.56 ,  3.471,  3.488,  3.473,
#         3.504,  3.492,  3.519,  3.5  ,  3.473,  3.549,  3.509,  3.443,
#         3.527,  3.452,  3.498,  3.425,  3.493,  3.564,  3.476,  3.442,
#         3.56 ,  3.485,  3.531,  3.508,  3.549,  3.444,  3.46 ,  3.478,
#         3.454,  3.497,  3.475,  3.498,  3.573,  3.477,  3.475,  3.407,
#         3.55 ,  3.585,  3.467,  3.511,  3.5  ,  3.421,  3.498,  3.38 ,
#         3.496,  3.49 ,  3.546,  3.582,  3.584,  3.502,  3.486,  3.457,
#         3.538,  3.432,  3.52 ,  3.561,  3.538,  3.586,  3.503,  3.588,
#         3.547,  3.476,  3.542,  3.47 ,  3.483,  3.419,  3.483,  3.543,
#         3.494,  3.469,  3.578,  3.475,  3.442,  3.422,  3.474,  3.439,
#         3.428,  3.496,  3.465,  3.501,  3.47 ,  3.502,  3.455,  3.48 ,
#         3.471,  3.584,  3.547,  3.407,  3.461,  3.578,  3.484,  3.484,
#         3.445,  3.516,  3.448,  3.484,  3.533,  3.5  ,  3.489,  3.489,
#         3.396,  3.569,  3.352,  3.511,  3.473,  3.486,  3.488,  3.362,
#         3.473,  3.52 ,  3.438,  3.499,  3.483,  3.49 ,  3.515,  3.364,
#         3.467,  3.463,  3.603,  3.486,  3.625,  3.511,  3.498,  3.643,
#         3.549,  3.495,  3.567,  3.424,  3.448,  3.629,  3.588,  3.503,
#         3.519,  3.55 ,  3.487,  3.456,  3.426,  3.456,  3.466,  3.569,
#         3.49 ,  3.51 ,  3.468,  3.48 ,  3.517,  3.505,  3.538,  3.537,
#         3.448,  3.507,  3.517,  3.503,  3.587,  3.445,  3.459,  3.439,
#         3.515,  3.46 ,  3.504,  3.43 ,  3.537,  3.517,  3.51 ,  3.445,
#         3.539,  3.335,  3.474,  3.526,  3.532,  3.536,  3.525,  3.519,
#         3.5  ,  3.56 ,  3.466,  3.48 ,  3.569,  3.528,  3.399,  3.414,
#         3.477,  3.528,  3.563,  3.394,  3.346,  3.487,  3.558,  3.377,
#         3.499,  3.415,  3.52 ,  3.452,  3.431,  3.441,  3.609,  3.515,
#         3.498,  3.508,  3.534,  3.52 ,  3.544,  3.45 ,  3.514,  3.491,
#         3.494,  3.462,  3.524,  3.523,  3.504,  3.399,  3.544,  3.575,
#         3.384,  3.456,  3.52 ,  3.503,  3.429,  3.474,  3.529,  3.419,
#         3.436,  3.509,  3.492,  3.526,  3.463,  3.524,  3.422,  3.435,
#         3.535,  3.365,  3.477,  3.578,  3.511,  3.463,  3.42 ,  3.473,
#         3.552,  3.415,  3.446,  3.502,  3.519,  3.48 ,  3.587,  3.457,
#         3.477,  3.49 ,  3.536,  3.488,  3.47 ,  3.519,  3.569,  3.541,
#         3.582,  3.48 ,  3.57 ,  3.521,  3.513,  3.584,  3.51 ,  3.501,
#         3.534,  3.464,  3.445,  3.531,  3.539,  3.474,  3.508,  3.491,
#         3.443,  3.592,  3.421,  3.48 ,  3.512,  3.499,  3.517,  3.52 ,
#         3.446,  3.493,  3.502,  3.576,  3.5  ,  3.484,  3.533,  3.538,
#         3.504,  3.532,  3.509,  3.497,  3.456,  3.442,  3.525,  3.443,
#         3.63 ,  3.366,  3.553,  3.465,  3.492,  3.47 ,  3.503,  3.563,
#         3.542,  3.525,  3.471,  3.445,  3.432,  3.386,  3.44 ,  3.473,
#         3.356,  3.506,  3.478,  3.506,  3.535,  3.464,  3.583,  3.516,
#         3.505,  3.506,  3.45 ,  3.467,  3.442,  3.494,  3.546,  3.422,
#         3.535,  3.502,  3.505,  3.507,  3.476,  3.422,  3.5  ,  3.42 ,
#         3.466,  3.597,  3.446,  3.495,  3.519,  3.492,  3.482,  3.461,
#         3.362,  3.476,  3.431,  3.514,  3.562,  3.511,  3.515,  3.448,
#         3.476,  3.519,  3.505,  3.53 ,  3.422,  3.505,  3.452,  3.488,
#         3.485,  3.372,  3.481,  3.506,  3.524,  3.463,  3.471,  3.448,
#         3.457,  3.48 ,  3.4  ,  3.474,  3.512,  3.526,  3.455,  3.485,
#         3.487,  3.451,  3.566,  3.531,  3.529,  3.5  ,  3.542,  3.523,
#         3.497,  3.559,  3.542,  3.432,  3.48 ,  3.493,  3.485,  3.471,
#         3.426,  3.449,  3.535,  3.506,  3.519,  3.513,  3.435,  3.559,
#         3.541,  3.511,  3.408,  3.484,  3.551,  3.479,  3.559,  3.394,
#         3.451,  3.576,  3.486,  3.502,  3.515,  3.505,  3.531,  3.471,
#         3.552,  3.487,  3.522,  3.398,  3.527,  3.466,  3.458,  3.498,
#         3.453,  3.538,  3.457,  3.464,  3.52 ,  3.422,  3.554,  3.566,
#         3.475,  3.511,  3.501,  3.577,  3.451,  3.491,  3.485,  3.442,
#         3.485,  3.528,  3.45 ,  3.559,  3.4  ,  3.467,  3.509,  3.458,
#         3.394,  3.502,  3.519,  3.503,  3.551,  3.556,  3.413,  3.465,
#         3.511,  3.549,  3.511,  3.415,  3.473,  3.485,  3.481,  3.482,
#         3.477,  3.53 ,  3.448,  3.485,  3.557,  3.619,  3.486,  3.446,
#         3.465,  3.504,  3.411,  3.593,  3.528,  3.564,  3.508,  3.462,
#         3.458,  3.544,  3.582,  3.454,  3.589,  3.488,  3.496,  3.418,
#         3.492,  3.464,  3.598,  3.56 ,  3.524,  3.436,  3.607,  3.477,
#         3.478,  3.463,  3.486,  3.448,  3.498,  3.476,  3.525,  3.513,
#         3.482,  3.462,  3.465,  3.471,  3.467,  3.563,  3.539,  3.557,
#         3.405,  3.481,  3.497,  3.533,  3.583,  3.542,  3.516,  3.632,
#         3.514,  3.511,  3.467,  3.514,  3.513,  3.373,  3.546,  3.43 ,
#         3.523,  3.446,  3.568,  3.431,  3.51 ,  3.425,  3.513,  3.567,
#         3.434,  3.565,  3.542,  3.516,  3.518,  3.532,  3.528,  3.388,
#         3.544,  3.556,  3.532,  3.566,  3.521,  3.441,  3.544,  3.536,
#         3.51 ,  3.529,  3.454,  3.537,  3.521,  3.511,  3.516,  3.522,
#         3.556,  3.532,  3.537,  3.551,  3.553,  3.422,  3.481,  3.518,
#         3.503,  3.537,  3.502,  3.481,  3.496,  3.483,  3.535,  3.431,
#         3.525,  3.495,  3.506,  3.475,  3.512,  3.487,  3.498,  3.497,
#         3.464,  3.456,  3.552,  3.519,  3.554,  3.509,  3.582,  3.485,
#         3.522,  3.486,  3.458,  3.363,  3.433,  3.422,  3.505,  3.436,
#         3.407,  3.454,  3.471,  3.521,  3.499,  3.493,  3.493,  3.516,
#         3.462,  3.467,  3.397,  3.599,  3.471,  3.463,  3.502,  3.498,
#         3.459,  3.546,  3.553,  3.443,  3.402,  3.46 ,  3.663,  3.444,
#         3.466,  3.552,  3.552,  3.454,  3.545,  3.604,  3.499,  3.536,
#         3.586,  3.554,  3.468,  3.427,  3.543,  3.531,  3.51 ,  3.498,
#         3.446,  3.451,  3.555,  3.463,  3.495,  3.457,  3.465,  3.516,
#         3.517,  3.447,  3.436,  3.458,  3.483,  3.491,  3.491,  3.449,
#         3.519,  3.535,  3.518,  3.442,  3.518,  3.464,  3.481,  3.585,
#         3.605,  3.407,  3.465,  3.575,  3.463,  3.53 ,  3.507,  3.391,
#         3.553,  3.505,  3.576,  3.606,  3.481,  3.508,  3.538,  3.603,
#         3.569,  3.488,  3.476,  3.56 ,  3.421,  3.533,  3.517,  3.441,
#         3.576,  3.514,  3.52 ,  3.481,  3.481,  3.444,  3.451,  3.475,
#         3.559,  3.426,  3.391,  3.46 ,  3.496,  3.549,  3.442,  3.473,
#         3.581,  3.53 ,  3.437,  3.485,  3.519,  3.538,  3.471,  3.514,
#         3.503,  3.478,  3.542,  3.485,  3.472,  3.513,  3.509,  3.582,
#         3.513,  3.544,  3.436,  3.457,  3.471,  3.471,  3.499,  3.564,
#         3.508,  3.529,  3.537,  3.514,  3.441,  3.499,  3.469,  3.535,
#         3.444,  3.437,  3.361,  3.543,  3.529,  3.496,  3.492,  3.459,
#         3.416,  3.455,  3.518,  3.412,  3.52 ,  3.523,  3.482,  3.411,
#         3.482,  3.462,  3.49 ,  3.546,  3.44 ,  3.405,  3.564,  3.43 ,
#         3.544,  3.469,  3.423,  3.441,  3.5  ,  3.571,  3.456,  3.588,
#         3.518,  3.475,  3.438,  3.426,  3.474,  3.515,  3.497,  3.501,
#         3.434,  3.54 ,  3.435,  3.489,  3.529,  3.525,  3.498,  3.49 ,
#         3.434,  3.467,  3.536,  3.501,  3.525,  3.49 ,  3.46 ,  3.445,
#         3.487,  3.497,  3.466,  3.468,  3.51 ,  3.604,  3.422,  3.488,
#         3.512,  3.472,  3.495,  3.537,  3.463,  3.494,  3.365,  3.519,
#         3.403,  3.521,  3.526,  3.602,  3.502,  3.579,  3.443,  3.435,
#         3.497,  3.457,  3.519,  3.483,  3.511,  3.465,  3.508,  3.451,
#         3.481,  3.465,  3.473,  3.509,  3.42 ,  3.471,  3.439,  3.473,
#         3.514,  3.441,  3.484,  3.485,  3.431,  3.491,  3.525,  3.501,
#         3.49 ,  3.455,  3.524,  3.491,  3.414,  3.467,  3.546,  3.566,
#         3.513,  3.505,  3.494,  3.479,  3.484,  3.51 ,  3.527,  3.431,
#         3.485,  3.488,  3.469,  3.44 ,  3.495,  3.497,  3.52 ,  3.515,
#         3.509,  3.429,  3.491,  3.438,  3.438,  3.475,  3.607,  3.641,
#         3.594,  3.533,  3.505,  3.499,  3.45 ,  3.532,  3.496,  3.535,
#         3.481,  3.471,  3.473,  3.529,  3.442,  3.502,  3.549,  3.54 ,
#         3.466,  3.445,  3.502,  3.465,  3.478,  3.546,  3.489,  3.522,
#         3.494,  3.453,  3.473,  3.468,  3.512,  3.5  ,  3.46 ,  3.458,
#         3.493,  3.546,  3.516,  3.444,  3.481,  3.563,  3.477,  3.455,
#         3.591,  3.511,  3.435,  3.505,  3.522,  3.444,  3.374,  3.613,
#         3.427,  3.568,  3.539,  3.428,  3.571,  3.573,  3.492,  3.573,
#         3.463,  3.527,  3.537,  3.485,  3.459,  3.445,  3.509,  3.514,
#         3.514,  3.467,  3.471,  3.554,  3.563,  3.46 ,  3.563,  3.525,
#         3.541,  3.535,  3.663,  3.528,  3.444,  3.446,  3.509,  3.401,
#         3.572,  3.488,  3.503,  3.462,  3.484,  3.545,  3.594,  3.469,
#         3.551,  3.542,  3.55 ,  3.456,  3.467,  3.569,  3.395,  3.477])

# %%
Table().with_columns('Average', group_averages).hist()
plots.show()

# %% [markdown]
# **Last Review Question**
